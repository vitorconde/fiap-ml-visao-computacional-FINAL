# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# > Atenção: este notebook foi desenhado para funcionar no **Google Collab**. Se pretende executar localmente prefira a versão local deste notebook, sem o sufixo ```-collab```.
#
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/NORMAL2-IM-1422-0001.jpeg?raw=1">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Pedro Zanela da Silva             | RM 339767      | `17IA` |
# | Vitor Conde de Souza             | RM 339766      | `17IA` |
# | Rafael Tupina da Rocha             | RM 339888      | `17IA` |
# | Vinicius de Carvalho Viana             | RM 338939      | `17IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/pneumonia.jpeg?raw=1">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/raiox.png?raw=1" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
# Note que as imagens de pneumonia bacteria e viral estão misturadas dentro da pasta ```PNEUMONIA```. É necessário separar as imagens manualmente tendo como base o sufixo. As imagens que terminal com ```_virus``` se referem a pneumoria viral e as que terminam com ```_bacteria``` se referem a pneumonia bacteriana.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**:
# * Classe Normal = 1583 imagens
# * Classe Pneumonia Bacterial = 2780 imagens
# * Classe Pneumonia Viral = 1493 imagens

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Todas as bibliotecas já estão instaladas no Google Colab.
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

from tensorflow.keras.models import Sequential, load_model, model_from_json
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import Model, layers
from tensorflow.keras import optimizers

import tensorflow.keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %% [markdown]
# > Você pode _montar_ o drive do Google Drive se precisar e quiser armazenar as imagens nesta plataforma. Como o Colab é efêmero, se você copiar os arquivos para o ambiente eles serão apagados depois do fim da sessão. Acesse [esta](https://medium.com/@maxwellcsm/colaboratory-acessando-os-arquivos-do-google-drive-d08ef9157dbf) referência para saber mais como o recurso funciona, inclusive recomenda-se essa abordagem de montar o próprio Google Drive.
#
# Se não for utilizar o Google Drive, crie as pastas que serão utilizadas para armazenar as imagens.

# %% [markdown]
# ### 4.3.1 Utilizando Google Drive
#
# Se usar o Google Drive para armazenar as imagens utilize o comando abaixo para montar seu drive.
# Você pode navegar pelas pastas pelo painel ao lado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 4.3.2 Utilizando o armazenamento efêmero
#
# Se optar pelo armazenamento efêmero você precisa enviar os arquivos de imagens (arrastar e soltar) para as pastas que deverão ser criadas pelo comando a seguir.

# %%
# !mkdir raiox/
# !mkdir raiox/normal
# !mkdir raiox/pneumonia_bacteriana
# !mkdir raiox/pneumonia_viral

# %%
# Separa automaticamente as imagens de pneumonia bacteriana e viral
lista_ls = os.listdir('/content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/chest_xray/val/PNEUMONIA')

for itens in lista_ls:
  # print(itens)
  procurar_por_bacteria = itens.find("bacteria")
  procurar_por_virus = itens.find("virus")
  if procurar_por_bacteria > 0:
    print(itens," migrado para pasta de Bacterias (bacteria_img)")
    os.system("mv /content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/chest_xray/val/PNEUMONIA/"+itens+" /content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/raiox/pneumonia_bacteriana/")
  elif procurar_por_virus > 0:
    print(itens," migrado para pasta de Vírus (virus_img)")
    os.system("mv /content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/chest_xray/val/PNEUMONIA/"+itens+" /content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/raiox/pneumonia_viral")

# %% [markdown]
# Defina o nome da pasta onde contém as sub-pastas referente aos 3 tipos de classe. Se optar pelo armazenamento efêmero a pasta será ```raiox```. Se optar pelo Goolge Drive, indique o caminho da pasta.

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.20
nome_pasta_raiz_imagens = "/content/drive/MyDrive/FIAP/MBA_IA_e_Machine_Learning/Visao_Computacional/archive/raiox"

# %% [markdown]
# O caminho abaixo da pasta ```raiox``` pode ser alterado caso você opte por utilizar uma pasta específica do seu Google Drive. Neste caso, certifique que dentro delas tem as sub-pastas referentes as imagens normal, pneumonia bacteriana e viral.

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 4686 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 1170 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2},
#  {'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:
#
# ResNet50 é uma rede residual com 50 camadas.
# O avanço na arquitetura da ResNet nos permite treinar redes
# neurais extremamente profundas, com mais de 150 camadas. A
# arquitetura da ResNet50 possui duas características principais:
# *   “*Identity shortcut connections*”: uma estratégia de “atalhos” ou “conexões de salto”, que pulam pares de grupos de camadas convolucionais. São também chamadas *gated units* ou *gated recurrent units*, apesar de não apresentarem
# uma recorrência no sentido tradicional dos modelos de redes neurais recorrentes;
#
# *   foco pesado em normalização de lotes (*batch normalization*).
#
#
# De forma simplificada, a ideia dos atalhos na ResNet50 é evitar que a rede, muito profunda, morra por esvanecimento de gradientes através do empilhamento de mapeamentos de identidades que, do ponto de vista matemático, estão simplesmente empilhando camadas que não fazem nada. Com isso, como mostra a imagem abaixo , a ResNet50 utiliza, num determinado ponto, um sinal que é a soma do sinal produzido pelas duas camadas convolucionais anteriores somado ao sinal transmitido diretamente do ponto anterior a estas camadas, juntando um sinal processado com um sinal de uma etapa anterior no processamento
#
#
# ![image.png](data:image/png;base64,...)
#
#
# A arquitetura básica de uma ResNet qualquer é descrita na imagem abaixo. É aplicada na entrada um bloco de preenchimento zero de (3,3). No Estágio 1, a Convolução 2D tem 64 filtros de forma (7,7) e usa uma passada de (2,2). O BatchNorm é aplicado ao eixo dos canais da entrada. O MaxPooling usa uma janela (3,3) e uma passada (2,2). No Estágio 2, o bloqueio convolucional usa três conjuntos de filtros. Os 2 blocos de identidade usam três conjuntos de filtros. Estágio 3, o bloqueio convolucional usa três conjuntos de filtros. Os 3 blocos de identidade usam três conjuntos de filtros. No Estágio 4, o bloco convolucional usa três conjuntos de filtros de tamanho. Os 5 blocos de identidade usam três conjuntos de filtros. Estágio 5, o bloqueio convolucional usa três conjuntos de filtros. Os 2 blocos de identidade usam três conjuntos de filtros. O Average Pooling (Agrupamento médio) 2D usa uma janela de forma (2,2). O flatten (nivelamento da camada) não possui nenhum hiperparâmetro ou nome. E a camada totalmente conectada (Densa) reduz sua entrada para o número de classes usando uma ativação Softmax
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE
qtde_classes = 3

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE
qtde_epocas = 15

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 49s 1s/step - loss: 1.5850 - precision_score: 0.5906 - recall_score: 0.5250 - f1_score: 0.5550 - val_loss: 1.3453 - val_precision_score: 0.5165 - val_recall_score: 0.5063 - val_f1_score: 0.5113
# Epoch 2/15
# 5/5 [==============================] - 5s 1s/step - loss: 1.0660 - precision_score: 0.6223 - recall_score: 0.5625 - f1_score: 0.5900 - val_loss: 0.7801 - val_precision_score: 0.6434 - val_recall_score: 0.5437 - val_f1_score: 0.5891
# Epoch 3/15
# 5/5 [==============================] - 5s 1s/step - loss: 0.7277 - precision_score: 0.7070 - recall_score: 0.6250 - f1_score: 0.6624 - val_loss: 0.6890 - val_precision_score: 0.7414 - val_recall_score: 0.6375 - val_f1_score: 0.6842
# Epoch 4/15
# 5/5 [==============================] - 4s 950ms/step - loss: 0.7463 - precision_score: 0.7581 - recall_score: 0.6625 - f1_score: 0.7053 - val_loss: 0.9051 - val_precision_score: 0.6977 - val_recall_score: 0.6625 - val_f1_score: 0.6791
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**: Antes de avaliarmos o resultado, vamos entender o que significa cada métrica gerada pelo modelo:
#
#
# *   **Precision**: A precisão é a relação em que TP é o número de verdadeiros positivos e FP o número de falsos positivos. A precisão é, intuitivamente, a capacidade do classificador de não rotular como positiva uma amostra que é
# negativa. Fórmula:
#
# 𝑝𝑟𝑒𝑐𝑖𝑠𝑖𝑜𝑛 = 𝑇𝑃/(𝑇𝑃 + 𝐹𝑃)
#
#
# *  **recall**: O recall é a relação em que TP é o número de verdadeiros positivos e FN o número de falsos negativos. O recall é, intuitivamente, a capacidade do classificador de encontrar todas as amostras positivas. Fórmula:
#
# 𝑟𝑒𝑐𝑎𝑙𝑙 = 𝑇𝑃/(𝑇𝑃 + 𝐹𝑁)
#
#
# *  **f1-score**: O f1-score pode ser interpretado como uma média ponderada do precision e do recall, em que um f1-score alcança seu melhor valor em 1 e o pior escore em 0. A contribuição relativa de precision e recall para o f1-score é igual. Fórmula:
#
# 𝑓1 − 𝑠𝑐𝑜𝑟𝑒 = 2 * (𝑝𝑟𝑒𝑐𝑖𝑠𝑖𝑜𝑛 * 𝑟𝑒𝑐𝑎𝑙𝑙)/(𝑝𝑟𝑒𝑐𝑖𝑠𝑖𝑜𝑛 + 𝑟𝑒𝑐𝑎𝑙𝑙)

# %% [markdown]
# **Resposta**: considerando 15 épocas, é notavel que adquire um desempenho regular satisfatório , com scores de precisão em ascendência e gráfico de loss em descendencia, apesar do tempo para treinamento do modelo para cada classe (3 no caso), ter durado por volta de 5 minutos, evidentemente causado pelo processamento do transfer learning via res-net50 na qual compoe 50 camadas e que podem ser consideradas vias de preprocessamento.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: valor alcançado, com 15 épocas e com  20% de split para validação.
#
# Precisão:  81,75%, sensibilidade: 78,75%, e pontuação de validação: 80,20%

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:
# O modelo de RNC VGG16 foi proposto por K. Simonyan e A. Zisserman, trouxe como principal melhoria a sua sucessora AlexNet uma substituição de grandes filtros convolucionais (11 na primeira e 5 na segunda camada convolucional) por múltiplos filtros de tamanho 3 x 3 um após o outro, tal configuração é o que dá o nome de VGG16 (significa que a rede tem 16 camadas).
# A entrada para a primeira camada de convolução tem o tamanho padrão de 224 x 224, aceitando outros tamanhos. A imagem é passada através de uma pilha de camadas convolucionais onde os filtros foram usados com um campo receptivo pequeno de 3 x 3.
#
# ![image.png](data:image/png;base64,...)
#
# Na etapa do agrupamento espacial, temos cinco camadas considerando uma função de máximo. Esse agrupamento é executado em uma janela de 2 x 2 pixels. Três camadas totalmente conectadas seguem uma pilha de camadas convolucionais.
# As duas primeiras têm 4096 neurônios cada, a terceira executa a classificação, e por último temos a camada que é responsável por aplicar a função Softmax. Todas as camadas ocultas estão equipadas com a não linearidade do tipo Relu.
# A Tabela a seguir, mostra o esquema da arquitetura da rede VGG16.
#
#  ![image.png](data:image/png;base64,...)
#
# Simonyan e Zisserman (2014) acharam o treinamento VGG16 e VGG19 desafiadores especificamente em relação à convergência nas redes mais profundas, então, para facilitar o treinamento, eles primeiro treinaram versões menores de VGG com 11 camadas que serviram como inicializações para as redes maiores e mais profundas como a VGG16 e 19.

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_9 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 6s 1s/step - loss: 3.0805 - precision_score: 0.3819 - recall_score: 0.3688 - f1_score: 0.3750 - val_loss: 2.8935 - val_precision_score: 0.3540 - val_recall_score: 0.3313 - val_f1_score: 0.3421
# Epoch 2/15
# 5/5 [==============================] - 4s 989ms/step - loss: 1.8222 - precision_score: 0.4877 - recall_score: 0.4625 - f1_score: 0.4748 - val_loss: 1.9568 - val_precision_score: 0.4605 - val_recall_score: 0.4500 - val_f1_score: 0.4549
# Epoch 3/15
# 5/5 [==============================] - 4s 984ms/step - loss: 1.4267 - precision_score: 0.5734 - recall_score: 0.5625 - f1_score: 0.5679 - val_loss: 0.9246 - val_precision_score: 0.7137 - val_recall_score: 0.7000 - val_f1_score: 0.7067
# Epoch 4/15
# 5/5 [==============================] - 5s 1s/step - loss: 0.9064 - precision_score: 0.6861 - recall_score: 0.6687 - f1_score: 0.6773 - val_loss: 1.2261 - val_precision_score: 0.7090 - val_recall_score: 0.6938 - val_f1_score: 0.7012
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**: Os gráficos monstram a sua evolução ao decorrer de cada época. Podemos identificar que as etapas de treinamento e de teste iniciaram uma crescente na primeira e segunda épocas muito similares, após a terceira época evoluíram e regrediram sempre de maneira oposta, porém na última época voltaram a se encontrar e finalizar o f1-score praticamente com o mesmo percentual.
#
# Em relação a curva de loss, podemos identificar que as duas etapas (treino e teste) começaram com um valor elevado de perda, mas essa perda diminuiu bastante logo na terceira e quarta época. Lembrando que quanto mais diminuía o percentual de perda, mais aumentava os 3 primeiros percentuais (precision, recall e f1-score)
#
# O VGG16 compõe 16 camadas convolucionais , estas com composição neural suficiente de processamento para aderencia de 138 milhões de parametros e que (fatigavelmente) podem ser consideradas vias de preprocessamento.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: valor alcançado, com 15 épocas e com  20% de split para validação.
#
# Precisão:  75,20%, sensibilidade: 74,37%, e pontuação de validação: 74,78%

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: a arquitetura VGG19 é uma composição de 19 camadas ultraprofunda, assim como VGG16 faz parte da arquitetura VGG na qual a principal caracteristica é usar filtros convolucionais muito pequenos (3x3) na qual hoje ainda são os preferidos na comunidade por serem mais utilizados para extração de caracteristicas de imagens, em diferença com o resnet50 na qual pode ser focado, inclusive, fora do campo da visão computacional e mais utilizado em processos mais performáticos de classificação.
#
# pode ser utilizado para obtenção de caracteristicas faciais , tanto quanto outras caracteristicas menores para ajuste de classificação , localização , entre outros, obtendo resultados superiores ao VGG16 por possuir maior densidade de rede e camadas e consequentemente durar mais temnpo no processo de treinamento, inclusive, para transfer learning.
#
# Seu time de pesquisa e desenvolvimento foi vencedor em primeiro e segundo lugar nos campos da localização e classificação do evento ImageNet LSVRC Challenge em 2014 com seu modelo alcançando 92.7% top 5 de teste de acurácia em ImageNet

# %% [markdown]
# Configuração das Arquiteturas VGG
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Comparado com o VGG16, o VGG19 é um pouco melhor, mas requer mais memória. O modelo VGG16 é composto de camadas de convoluções, camadas de pooling máximas e camadas totalmente conectadas. O total é de 16 camadas com 5 blocos e cada bloco com uma camada de pooling máxima. Semelhante ao VGG16, o VGG19 tem 19 camadas com camadas de convolução extras nos últimos três blocos. Com camadas profundas, o VGG16 e o VGG19 alcançam um ótimo desempenho na competição de imagem.

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_11 (InputLayer)        [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 7s 1s/step - loss: 5.4975 - precision_score: 0.4187 - recall_score: 0.4187 - f1_score: 0.4187 - val_loss: 5.2943 - val_precision_score: 0.2625 - val_recall_score: 0.2625 - val_f1_score: 0.2625
# Epoch 2/15
# 5/5 [==============================] - 4s 991ms/step - loss: 3.1259 - precision_score: 0.3587 - recall_score: 0.3438 - f1_score: 0.3510 - val_loss: 1.8763 - val_precision_score: 0.4972 - val_recall_score: 0.4875 - val_f1_score: 0.4921
# Epoch 3/15
# 5/5 [==============================] - 5s 1s/step - loss: 2.1799 - precision_score: 0.4625 - recall_score: 0.4625 - f1_score: 0.4625 - val_loss: 1.6826 - val_precision_score: 0.5351 - val_recall_score: 0.5125 - val_f1_score: 0.5234
# Epoch 4/15
# 5/5 [==============================] - 5s 1s/step - loss: 1.1752 - precision_score: 0.6472 - recall_score: 0.6250 - f1_score: 0.6358 - val_loss: 1.3068 - val_precision_score: 0.6384 - val_recall_score: 0.6000 - val_f1_score: 0.6184
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**: Os gráficos monstram a sua evolução ao decorrer de cada época. Podemos identificar que a etapa de teste obteve sempre uma crescente até mais ou menos a sétima época, após isso regrediu bem pouco seu percentual e por final finalizou a 15ª época com quase seu segundo melhor desempenho, perdendo apenas para a época 13. A etapa de treinamento iniciou com uma pequena queda logo na 1ª época, porém logo em seguida se recuperou e manteve um alinhamento bem próximo ao teste, finalizando com praticamente o mesmo percentual de acurácia. Tanto precisão, sensibilidade mantiveram um desempenho bastante similar, o f1-score por ser basicamente uma média ponderada das duas métricas, manteve também um desempenho extramente similar.
#
# Em relação a curva de loss, podemos identificar que as duas etapas (treino e teste) começaram com um valor elevado de perda, mas essa perda diminuiu bastante logo na terceira e quarta época. A oscilação entre as etapas de treino e teste foram diminuindo com o decorrer das épocas e as duas etapas desempenharam muito próximas uma da outra.
#
# O VGG19 compõe 19 camadas convolucionais , estas com composição neural suficiente de processamento para suporte de 19.6 bilhões de FLOPs e que (fatigavelmente) podem ser consideradas vias de preprocessamento.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**: valor alcançado, com 15 épocas e com 20% de split para validação.
#
# Precisão: 75,17%, sensibilidade: 73,75%, e pontuação de validação: 74,44%

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 81,75%   | 78,75%        | 80,20 %  |
# | VGG16    | 75,20%   | 74,37%       | 74,78 %  |
# | VGG19    | 75,17 %  | 73,75 %       | 74,44 %  |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Resposta**: A ResNet50 obteve resultados melhores em comparação as outras duas arquiteturas, VGG-16 e VGG-19. Isso mostra que a ResNet50 é mais precisa em classificar imagens de pacientes em condições normais e pacientes com pneumonia viral e bacteriana, enquanto a VGG-16 obtém um desempenho levemente superior à VGG-19 em precision e f1-score, mas um pouco inferior no recall.

# %% [markdown]
# **Por que a ResNet50 obteve resultados melhores do que VGG-16 e VGG-19?**
#
# A arquitetura VGG consiste em blocos, onde cada bloco é composto por camadas de convolução 2D e agrupamento máximo. VGGNet vem em duas versões, VGG16 e VGG19, onde 16 e 19 são o número de camadas em cada um deles, respectivamente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em uma Rede Neural Convolucional (CNN), conforme o número de camadas aumenta, também aumenta a capacidade do modelo de se ajustar a funções mais complexas. Portanto, mais número de camadas é sempre melhor. Esse é o problema.
#
# Os pesos de uma rede neural são atualizados usando o algoritmo de retropropagação. O algoritmo de retropropagação faz uma pequena alteração em cada peso de forma que a perda do modelo diminua. Como isso acontece? Ele atualiza cada peso de forma que dê um passo na direção ao longo da qual a perda diminui. Essa direção nada mais é do que o gradiente desse peso (em relação à perda).
# Usando a regra da cadeia, podemos encontrar esse gradiente para cada peso. É igual a (gradiente local) x (gradiente fluindo de frente).
#
# Aí vem o problema. Como esse gradiente continua fluindo de volta para as camadas iniciais, esse valor continua sendo multiplicado por cada gradiente local. Assim, o gradiente torna-se cada vez menor, tornando as atualizações nas camadas iniciais muito pequenas, aumentando consideravelmente o tempo de treinamento.
#
# Podemos resolver nosso problema se o gradiente local se tornar 1.
#
# Como pode o gradiente local ser 1, ou seja, a derivada de qual função seria sempre 1? A função de identidade!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Portanto, como esse gradiente é retropropagado, ele não diminui em valor porque o gradiente local é 1.
# A arquitetura ResNet, mostrada abaixo, agora deve fazer todo o sentido em relação a como não permitiria que o problema do gradiente de desaparecimento ocorresse. ResNet significa Rede Residual.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Essas conexões de salto agem como superestradas de gradiente, permitindo que o gradiente flua sem obstáculos. E por isso o ResNet vem em versões como ResNet50, ResNet101 e ResNet152.

# %% [markdown]
# ## 4.8 Abordagem adicional (obrigatório) -> **Arquitetura EfficientNetB6**
#
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE
from tensorflow.keras.applications import EfficientNetB6

conv_base = EfficientNetB6(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# rescaling_2 (Rescaling)         (None, None, None, 3 0           input_4[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, None, None, 3 7           rescaling_2[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, None, None, 3 0           normalization_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 217s 38s/step - loss: 0.9575 - precision_score: 0.5349 - recall_score: 0.3375 - f1_score: 0.4066 - val_loss: 0.8786 - val_precision_score: 0.6802 - val_recall_score: 0.5875 - val_f1_score: 0.6300
# Epoch 2/15
# 5/5 [==============================] - 163s 37s/step - loss: 0.8046 - precision_score: 0.7477 - recall_score: 0.6062 - f1_score: 0.6674 - val_loss: 0.6633 - val_precision_score: 0.7881 - val_recall_score: 0.6687 - val_f1_score: 0.7226
# Epoch 3/15
# 5/5 [==============================] - 146s 32s/step - loss: 0.6664 - precision_score: 0.7870 - recall_score: 0.6687 - f1_score: 0.7227 - val_loss: 0.6247 - val_precision_score: 0.7756 - val_recall_score: 0.6438 - val_f1_score: 0.7025
# Epoch 4/15
# 5/5 [==============================] - 137s 30s/step - loss: 0.6488 - precision_score: 0.7596 - recall_score: 0.6812 - f1_score: 0.7180 - val_loss: 0.6775 - val_precision_score: 0.7541 - val_recall_score: 0.6875 - val_f1_score: 0.7189
# ...

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem adicional
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | EfficientNetB7 | 84,78%   | 78,12%        | 81,26 %  |

# %% [markdown]
# **Comparação com as arquiteturas anteriores**
#
# A arquitetura EfficientNetB6 obteve um percentual de precisão (84,78%) maior que todas as outras arquiteturas, a que chegou mais próxima foi a ResNet50 com 81,75%, uma diferença de 3,03%. Já a sensibilidade do Resnet50 (78,75%) teve um desempenho levemente maior que essa (78,12%), diferença de 0,63%. Consequentemente pela maior diferença da precisão a favor do EfficientNetB6, o f1-score teve um melhor resultado para essa nova arquitetura, um total de 81,26% do EfficienteNetB6 contra 80,20% do ResNet50.

# %% [markdown]
# **Avaliação dos gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*):**
#
# Podemos identificar que a etapa de teste obteve um bom resulado tanto de precisão quanto de sensibilidade logo na primeira época, diferentemente da etapa de treino que iniciou bem abaixo, porém evoluiu bem ao decorrer das épocas. Nessa arquitetura é curioso que ao final da última época treino e teste ficaram com uma diferença considerável no percentual dos 3 primeiros gráficos, teste obteve um resultado melhor do que a etapa de treino, mas ambas terminaram com uma performance muito boa.
#
# Em relação a curva de loss, podemos identificar que as duas etapas (treino e teste) começaram com um valor elevado de perda, mas essa perda diminuiu ao decorrer das épocas. Diferentemente das outras arquiteturas, ela foi diminuindo aos poucos até ter uma queda brusca (na etapa de teste) na última época.

# %% [markdown]
# # **Arquitetura:**
#
# No EfficientNet, o modelo de linha de base EfficientNet-B0 é construído usando convolução de gargalo invertido móvel (MBConv) semelhante a MobileNetV2 e MnasNet . As melhorias no modelo de linha de base são feitas posteriormente para obter a família de EfficientNets
#
# Deixe-me fornecer uma breve descrição sobre o que é MBConv e outros blocos de construção para o EfficientNet. Os blocos MBConv nada mais são do que os blocos residuais invertidos que foram originalmente propostos na arquitetura MobineNetV2 CNN.
#
# No bloco residual normal , o fluxo da rede geralmente vai de uma estrutura ampla a estreita para uma estrutura ampla em relação ao número de canais. A camada final é trazida de volta à forma da entrada a ser adicionada (o objetivo do bloco residual é evitar o gradiente de desaparecimento).
#
# **Bloco Resídual:**
#
# ![image.png](data:image/png;base64,...)
#
#
#
# No bloco residual invertido, as camadas vão de estreitas a largas a estreitas, o que é o oposto do bloco residual. Portanto, ele inicialmente pega uma entrada dimensional baixa e a expande com uma camada convolucional de 1 x 1, seguida por uma convolução sábia de profundidade 3 x 3 e de volta para a forma de entrada usando uma camada convolucional 1 x 1.
#
# **Bloco Resídual Invertido:**
#
# ![image.png](data:image/png;base64,...)
#
# A razão por trás do bloco residual invertido é que, no bloco residual original, a camada de expansão intermediária é um mero detalhe de implementação. As informações ainda podem ser pertencentes à baixa dimensão, resultando em menos necessidade computacional e tempo de execução.
#
# A arquitetura da linha de base EfficientNet consiste em camadas profundas de blocos MBConv:
#
# ![image.png](data:image/png;base64,...)
#
# EfficientNets B1 a B7 são obtidos usando diferentes coeficientes de escala. O modelo geral e a comparação de desempenho conforme declarado no documento original são fornecidos abaixo:
# ![image.png](data:image/png;base64,...)
#
# Como o número de parâmetros para computação é convenientemente pequeno, o EfficientNet pode ser muito bem usado para processamento rápido, especialmente em MobileAI.
#
# A EfficientNet abriu uma ampla arena de pesquisa para melhorar os resultados de várias tarefas de visão computacional. Isso potencialmente ajudou a fornecer uma boa solução na seleção da profundidade, largura e resolução do modelo para obter resultados máximos a partir dele.
#
# Depois que a equipe de IA do Google publicou este modelo, houve algumas pesquisas que consideraram o EfficientNet como um backbone - FixEfficientNet que otimiza a discrepância de resolução, EfficientDet que pode ser amplamente usado em tarefas de detecção de objetos.

# %% [markdown]
# **Quais os valores de precisão (precision), sensibilidade (recall) e pontuação de validação (f1-score)?**
#
# **Resposta:** valor alcançado, com 15 épocas e com 20% de split para validação.
#
# Precisão: 84,78%, sensibilidade: 78,12%, e pontuação de validação: 81,26%
